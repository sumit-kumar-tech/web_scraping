# %% [markdown]
# # Import

# %%
import requests

# %%
print(requests.__version__)
# Out:
# 2.32.3

# %%
uri = "http://api.github.com"
response = requests.get(uri)

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.content[:1000]
# Out:
# b'{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_searc'

# %%
response.content
# Out:
# b'{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","label_search_url":"https://api.github.com/search/labels?q={query}&repository_id={repository_id}{&page,per_page}","notifications_url":"https://api.github.com/notifications","organization_url":"https://api.github.com/orgs/{org}","organization_repositories_url":"https://api.github.com/orgs/{org}/repos{?type,page,per_page,sort}","organization_teams_url":"https://api.github.com/orgs/{org}/teams","public_gists_url":"https://api.github.com/gists/public","rate_limit_url":"https://api.github.com/rate_limit","repository_url":"https://api.github.com/repos/{owner}/{repo}","repository_search_url":"https://api.github.com/search/repositories?q={query}{&page,per_page,sort,order}","current_user_repositories_url":"https://api.github.com/user/repos{?type,page,per_page,sort}","starred_url":"https://api.github.com/user/starred{/owner}{/repo}","starred_gists_url":"https://api.github.com/gists/starred","topic_search_url":"https://api.github.com/search/topics?q={query}{&page,per_page}","user_url":"https://api.github.com/users/{user}","user_organizations_url":"https://api.github.com/user/orgs","user_repositories_url":"https://api.github.com/users/{user}/repos{?type,page,per_page,sort}","user_search_url":"https://api.github.com/search/users?q={query}{&page,per_page,sort,order}"}'

# %% [markdown]
# # Query Parameters

# %%
uri = "http://api.github.com/search/repositories"

# %%
params = {
    "q":"web_scraping+language:python"
}

# %%
result = requests.get(uri,params=params)

# %%
result
# Out:
# <Response [200]>

# %%
result.content
# Out:
# b'{"total_count":173,"incomplete_results":false,"items":[{"id":1696822,"node_id":"MDEwOlJlcG9zaXRvcnkxNjk2ODIy","name":"pattern","full_name":"clips/pattern","private":false,"owner":{"login":"clips","id":765924,"node_id":"MDEyOk9yZ2FuaXphdGlvbjc2NTkyNA==","avatar_url":"https://avatars.githubusercontent.com/u/765924?v=4","gravatar_id":"","url":"https://api.github.com/users/clips","html_url":"https://github.com/clips","followers_url":"https://api.github.com/users/clips/followers","following_url":"https://api.github.com/users/clips/following{/other_user}","gists_url":"https://api.github.com/users/clips/gists{/gist_id}","starred_url":"https://api.github.com/users/clips/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/clips/subscriptions","organizations_url":"https://api.github.com/users/clips/orgs","repos_url":"https://api.github.com/users/clips/repos","events_url":"https://api.github.com/users/clips/events{/privacy}","received_events_url":"https://api.github.com/users/clips/received_events","type":"Organization","user_view_type":"public","site_admin":false},"html_url":"https://github.com/clips/pattern","description":"Web mining module for Python, with tools for scraping, natural language processing, machine learning, network analysis and visualization.","fork":false,"url":"https://api.github.com/repos/clips/pattern","forks_url":"https://api.github.com/repos/clips/pattern/forks","keys_url":"https://api.github.com/repos/clips/pattern/keys{/key_id}","collaborators_url":"https://api.github.com/repos/clips/pattern/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/clips/pattern/teams","hooks_url":"https://api.github.com/repos/clips/pattern/hooks","issue_events_url":"https://api.github.com/repos/clips/pattern/issues/events{/number}","events_url":"https://api.github.com/repos/clips/pattern/events","assignees_url":"https://api.github.com/repos/clips/pattern/assignees{/user}","branches_url":"https://api.github.com/repos/clips/pattern/branches{/branch}","tags_url":"https://api.github.com/repos/clips/pattern/tags","blobs_url":"https://api.github.com/repos/clips/pattern/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/clips/pattern/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/clips/pattern/git/refs{/sha}","trees_url":"https://api.github.com/repos/clips/pattern/git/trees{/sha}","statuses_url":"https://api.github.com/repos/clips/pattern/statuses/{sha}","languages_url":"https://api.github.com/repos/clips/pattern/languages","stargazers_url":"https://api.github.com/repos/clips/pattern/stargazers","contributors_url":"https://api.github.com/repos/clips/pattern/contributors","subscribers_url":"https://api.github.com/repos/clips/pattern/subscribers","subscription_url":"https://api.github.com/repos/clips/pattern/subscription","commits_url":"https://api.github.com/repos/clips/pattern/commits{/sha}","git_commits_url":"https://api.github.com/repos/clips/pattern/git/commits{/sha}","comments_url":"https://api.github.com/repos/clips/pattern/comments{/number}","issue_comment_url":"https://api.github.com/repos/clips/pattern/issues/comments{/number}","contents_url":"https://api.github.com/repos/clips/pattern/contents/{+path}","compare_url":"https://api.github.com/repos/clips/pattern/compare/{base}...{head}","merges_url":"https://api.github.com/repos/clips/pattern/merges","archive_url":"https://api.github.com/repos/clips/pattern/{archive_format}{/ref}","downloads_url":"https://api.github.com/repos/clips/pattern/downloads","issues_url":"https://api.github.com/repos/clips/pattern/issues{/number}","pulls_url":"https://api.github.com/repos/clips/pattern/pulls{/number}","milestones_url":"https://api.github.com/repos/clips/pattern/milestones{/number}","notifications_url":"https://api.github.com/repos/clips/pattern/notifications{?since,all,participating}","labels_url":"https://api.github.com/repos/clips/pattern/labels{/name}","releases_url":"https://api.github.com/repos/clips/pattern/releases{/i ...
